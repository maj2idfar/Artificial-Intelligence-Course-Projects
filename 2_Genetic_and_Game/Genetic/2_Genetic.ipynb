# %%
import random
from copy import deepcopy

RETURN_WEIGHT = 7
RISK_WEIGHT = 1
NUM_OF_PURCHASED_STOCKS_WEIGHT = 0.01

NEEDED_RETURN = 10
HIGHEST_RISK = 0.6
LEAST_STOCKS = 30

class Stock:
    _name: str
    _return: float
    _risk: float

    def __init__(self, n, p, r):
        self._name = n
        self._return = p
        self._risk = r

class Chromososme:
    genes: list[float]

    def __init__(self, g):
        self.genes = g

    def set_sum_to_one(self):
        total = sum(self.genes)
        self.genes = [a/total for a in self.genes]

    def get_num_of_purhased_stocks(self):
        num_of_purchased_stocks = 0

        for i in range(len(self.genes)):
            if self.genes[i] != 0:
                num_of_purchased_stocks += 1
        
        return num_of_purchased_stocks
    
    def fitness_function(self, stocks: list[Stock]):
        fitness = 0

        for i in range(len(self.genes)):
            fitness += self.genes[i] * stocks[i]._return * RETURN_WEIGHT
            fitness -= self.genes[i] * stocks[i]._risk * RISK_WEIGHT

        fitness += self.get_num_of_purhased_stocks() * NUM_OF_PURCHASED_STOCKS_WEIGHT

        return fitness

    def mutate(self, probability):
        for i in range(len(self.genes)):
            if random.uniform(0, 1) < probability:
                self.genes[i] = random.random()

        self.set_sum_to_one()

def uniform_cross_over(parents: list[Chromososme], probability):
    num_of_genes = len(parents[0].genes)

    childs = [Chromososme([0]*num_of_genes), 
              Chromososme([0]*num_of_genes)]
 
    for i in range(num_of_genes):
        for_0 = 1 if random.uniform(0, 1) < probability else 0

        childs[0].genes[i] = parents[for_0].genes[i]
        childs[1].genes[i] = parents[1 - for_0].genes[i]

    childs[0].set_sum_to_one()
    childs[1].set_sum_to_one()

    return childs
    
class PortfolioManagement:
    stocks_information: list[Stock]
    population: list[Chromososme]
    population_size: int
    fitness_scores: list
    num_of_elites: int
    generation_number: int
    mating_pool: list[Chromososme]
    cross_over_rate: int
    cross_over_probability: int
    mutation_rate: int
    mutation_probability: int

    def __init__(self,
                 population_size,
                 num_of_elites,
                 cross_over_rate,
                 cross_over_probability,
                 mutation_rate,
                 mutation_probability):
        
        self.stocks_information = []
        self.population = []
        self.population_size = population_size
        self.fitness_scores = []
        self.num_of_elites = num_of_elites
        self.generation_number = 1
        self.mating_pool = []
        self.cross_over_rate = cross_over_rate
        self.cross_over_probability = cross_over_probability
        self.mutation_rate = mutation_rate
        self.mutation_probability = mutation_probability 

    def is_goal(self, chromosome: Chromososme):
        total_risk = total_return = 0

        for i in range(len(self.stocks_information)):
            total_risk += chromosome.genes[i] * self.stocks_information[i]._risk
            total_return += chromosome.genes[i] * self.stocks_information[i]._return

        if total_return >= NEEDED_RETURN and total_risk <= HIGHEST_RISK and chromosome.get_num_of_purhased_stocks() >= LEAST_STOCKS:
            print("Answer:")
            print("Return:", total_return)
            print("Risk:", total_risk)
            print("Num of Purchased Stocks:", chromosome.get_num_of_purhased_stocks())
            
            return True
        
    def read_input(self, filename):
        with open(filename, 'r') as file:
            next(file)

            for line in file:
                _number, _name, _risk, _return = line.split(',')
                self.stocks_information.append(Stock(_name, float(_return), float(_risk)))

    def generate_first_generation(self):
        num_of_genes = len(self.stocks_information)
        self.population: list[Chromososme] = [None] * self.population_size

        for i in range(self.population_size):
            genes = []
            for j in range(num_of_genes):
                genes.append(random.random())

            self.population[i] = Chromososme(genes)
            self.population[i].set_sum_to_one()

        self.generation_number = 1

    def select_parents_for_mating_pool(self):
        total = ((len(self.population))*(len(self.population)+1))/2
        
        self.mating_pool = []
        for i in range(self.population_size - self.num_of_elites):   
            random_number = int(random.random()*total)
            s_index = 0

            for j in range(len(self.population)):
                s_index += j+1

                if s_index >= random_number:
                    self.mating_pool.append(self.fitness_scores[j][0])
                    break

        random.shuffle(self.mating_pool)
    
    def rank_by_fitness_scores(self):
        self.fitness_scores = []

        for chromosome in self.population:
            self.fitness_scores.append((chromosome, chromosome.fitness_function(self.stocks_information)))

        self.fitness_scores.sort(key = lambda x: x[1])

    def generate_next_generation(self):
        self.rank_by_fitness_scores()
        
        self._print()

        for i in range(-1, -10, -1):
            if self.is_goal(self.fitness_scores[i][0]):
                return self.fitness_scores[i][0]
            
        self.select_parents_for_mating_pool()

        next_population = []

        for i in range(self.population_size-1, self.population_size-self.num_of_elites-1, -1):
            next_population.append(self.fitness_scores[i][0])
        
        for i in range(0, len(self.mating_pool)-1, 2):
            childs = [self.mating_pool[i], self.mating_pool[i+1]]

            if random.uniform(0, 1) < self.cross_over_rate:
                childs = uniform_cross_over([childs[0], childs[1]], self.cross_over_probability)

            if random.uniform(0, 1) < self.mutation_rate:
                childs[0].mutate(self.mutation_probability)

            if random.uniform(0, 1) < self.mutation_rate:
                childs[1].mutate(self.mutation_probability)

            next_population.append(childs[0])
            next_population.append(childs[1])

        self.population = next_population
        self.generation_number += 1

        return None

    def solve(self):
        self.generate_first_generation()

        while True:
            answer = self.generate_next_generation()

            if answer != None:
                return answer
            
    def _print(self):
        print("Generation Number:", self.generation_number)
        print("Best Fitness Score:", self.fitness_scores[-1][1])
        print("Worst Fitness Score:", self.fitness_scores[0][1])
        fitness_sum = sum([x[1] for x in self.fitness_scores])
        print("Average of Fitness Scores:", fitness_sum / len(self.fitness_scores))
        print("------------------------------------------------------")

manager = PortfolioManagement(population_size= 100,
                              num_of_elites= 10,
                              cross_over_rate= 0.5,
                              cross_over_probability= 0.5,
                              mutation_rate= 0.1,
                              mutation_probability= 0.1)

manager.read_input("Dataset/sample.csv")
manager.solve()
# Out:
# Generation Number: 1
# Best Fitness Score: 9.464128926549202
# Worst Fitness Score: 8.151423762363336
# Average of Fitness Scores: 8.869492186559247
# ------------------------------------------------------
# Generation Number: 2
# Best Fitness Score: 9.84219613289006
# Worst Fitness Score: 6.5671636922020795
# Average of Fitness Scores: 8.747848485093213
# ------------------------------------------------------
# Generation Number: 3
# Best Fitness Score: 11.6434974232291
# Worst Fitness Score: 7.282936760525849
# Average of Fitness Scores: 9.071745116410437
# ------------------------------------------------------
# Generation Number: 4
# Best Fitness Score: 15.701924711342398
# Worst Fitness Score: 5.888005807590453
# Average of Fitness Scores: 9.689219479269703
# ------------------------------------------------------
# Generation Number: 5
# Best Fitness Score: 14.552804869055276
# Worst Fitness Score: 7.282010386760373
# Average of Fitness Scores: 9.477066033122812
# ------------------------------------------------------
# Generation Number: 6
# Best Fitness Score: 14.552804869055276
# Worst Fitness Score: 5.94731416321398
# Average of Fitness Scores: 9.988138568194755
# ------------------------------------------------------
# Generation Number: 7
# Best Fitness Score: 15.113869044493136
# Worst Fitness Score: 6.600218907925148
# Average of Fitness Scores: 10.922428232050946
# ------------------------------------------------------
# Generation Number: 8
# Best Fitness Score: 16.362541790018035
# Worst Fitness Score: 6.451692973754138
# Average of Fitness Scores: 10.289670177031661
# ------------------------------------------------------
# Generation Number: 9
# Best Fitness Score: 19.162684973704664
# Worst Fitness Score: 6.756315610704299
# Average of Fitness Scores: 11.127809161896833
# ------------------------------------------------------
# Generation Number: 10
# Best Fitness Score: 19.162684973704664
# Worst Fitness Score: 7.192736506857964
# Average of Fitness Scores: 12.277965629991025
# ------------------------------------------------------
# Generation Number: 11
# Best Fitness Score: 21.086807627072645
# Worst Fitness Score: 7.562473635542444
# Average of Fitness Scores: 14.03824203199515
# ------------------------------------------------------
# Generation Number: 12
# Best Fitness Score: 21.086807627072645
# Worst Fitness Score: 6.801797055761736
# Average of Fitness Scores: 13.784154025226508
# ------------------------------------------------------
# Generation Number: 13
# Best Fitness Score: 21.27717787482262
# Worst Fitness Score: 7.051770397499531
# Average of Fitness Scores: 14.813278861659553
# ------------------------------------------------------
# Generation Number: 14
# Best Fitness Score: 22.144151089279486
# Worst Fitness Score: 7.238572235424673
# Average of Fitness Scores: 15.796819370238367
# ------------------------------------------------------
# Generation Number: 15
# Best Fitness Score: 22.144151089279486
# Worst Fitness Score: 7.296242036584003
# Average of Fitness Scores: 16.558012308346722
# ------------------------------------------------------
# Generation Number: 16
# Best Fitness Score: 24.768888291833665
# Worst Fitness Score: 7.062144588730652
# Average of Fitness Scores: 16.467262047215236
# ------------------------------------------------------
# Generation Number: 17
# Best Fitness Score: 24.768888291833665
# Worst Fitness Score: 7.7157854715366465
# Average of Fitness Scores: 18.02869664463871
# ------------------------------------------------------
# Generation Number: 18
# Best Fitness Score: 25.586319125026623
# Worst Fitness Score: 6.378957122123841
# Average of Fitness Scores: 17.401338890675255
# ------------------------------------------------------
# Generation Number: 19
# Best Fitness Score: 25.586319125026623
# Worst Fitness Score: 6.625040255883999
# Average of Fitness Scores: 17.943028150335575
# ------------------------------------------------------
# Generation Number: 20
# Best Fitness Score: 26.620722031624037
# Worst Fitness Score: 7.537486787351641
# Average of Fitness Scores: 19.598249488427403
# ------------------------------------------------------
# Generation Number: 21
# Best Fitness Score: 28.209437757635417
# Worst Fitness Score: 7.178725831800876
# Average of Fitness Scores: 20.521483384685745
# ------------------------------------------------------
# Generation Number: 22
# Best Fitness Score: 31.592515699241662
# Worst Fitness Score: 8.104379933973384
# Average of Fitness Scores: 22.751876567624926
# ------------------------------------------------------
# Generation Number: 23
# Best Fitness Score: 31.592515699241662
# Worst Fitness Score: 7.129444263572519
# Average of Fitness Scores: 20.334211847263138
# ------------------------------------------------------
# Generation Number: 24
# Best Fitness Score: 31.592515699241662
# Worst Fitness Score: 8.004203375138644
# Average of Fitness Scores: 22.95489889857856
# ------------------------------------------------------
# Generation Number: 25
# Best Fitness Score: 35.38631798976157
# Worst Fitness Score: 8.08951429725109
# Average of Fitness Scores: 25.27910308943607
# ------------------------------------------------------
# Generation Number: 26
# Best Fitness Score: 37.24514076855943
# Worst Fitness Score: 6.825246599121213
# Average of Fitness Scores: 23.420696544533804
# ------------------------------------------------------
# Generation Number: 27
# Best Fitness Score: 41.42709628652243
# Worst Fitness Score: 8.227890785307732
# Average of Fitness Scores: 26.804158778896326
# ------------------------------------------------------
# Generation Number: 28
# Best Fitness Score: 41.42709628652243
# Worst Fitness Score: 7.576430894710642
# Average of Fitness Scores: 24.191317186891943
# ------------------------------------------------------
# Generation Number: 29
# Best Fitness Score: 43.439657801005325
# Worst Fitness Score: 8.040313456788654
# Average of Fitness Scores: 26.06380896588225
# ------------------------------------------------------
# Generation Number: 30
# Best Fitness Score: 43.439657801005325
# Worst Fitness Score: 9.097997499703963
# Average of Fitness Scores: 27.030748729149085
# ------------------------------------------------------
# Generation Number: 31
# Best Fitness Score: 44.293602130721624
# Worst Fitness Score: 8.142949657057166
# Average of Fitness Scores: 30.791050080059954
# ------------------------------------------------------
# Generation Number: 32
# Best Fitness Score: 46.20327236793186
# Worst Fitness Score: 8.178052087709876
# Average of Fitness Scores: 29.72909782325091
# ------------------------------------------------------
# Generation Number: 33
# Best Fitness Score: 46.20327236793186
# Worst Fitness Score: 9.192725710536926
# Average of Fitness Scores: 32.99073083597437
# ------------------------------------------------------
# Generation Number: 34
# Best Fitness Score: 48.64475580933927
# Worst Fitness Score: 8.231410738748345
# Average of Fitness Scores: 33.499050697120545
# ------------------------------------------------------
# Generation Number: 35
# Best Fitness Score: 50.665720552532875
# Worst Fitness Score: 8.354522109897353
# Average of Fitness Scores: 33.324962597752766
# ------------------------------------------------------
# Generation Number: 36
# Best Fitness Score: 50.665720552532875
# Worst Fitness Score: 8.294536504002346
# Average of Fitness Scores: 35.11806440920251
# ------------------------------------------------------
# Generation Number: 37
# Best Fitness Score: 50.665720552532875
# Worst Fitness Score: 8.879374487120689
# Average of Fitness Scores: 36.55671688075157
# ------------------------------------------------------
# Generation Number: 38
# Best Fitness Score: 54.43737083986273
# Worst Fitness Score: 6.4877657448896935
# Average of Fitness Scores: 35.5684671322881
# ------------------------------------------------------
# Generation Number: 39
# Best Fitness Score: 54.43737083986273
# Worst Fitness Score: 8.738822414287617
# Average of Fitness Scores: 34.60267440387493
# ------------------------------------------------------
# Generation Number: 40
# Best Fitness Score: 55.93517094554298
# Worst Fitness Score: 8.24541141590357
# Average of Fitness Scores: 38.734258358229916
# ------------------------------------------------------
# Generation Number: 41
# Best Fitness Score: 55.93517094554298
# Worst Fitness Score: 8.368177095118469
# Average of Fitness Scores: 41.11176479672298
# ------------------------------------------------------
# Generation Number: 42
# Best Fitness Score: 55.93517094554298
# Worst Fitness Score: 8.78350988266983
# Average of Fitness Scores: 45.77127824575857
# ------------------------------------------------------
# Generation Number: 43
# Best Fitness Score: 59.265939424188566
# Worst Fitness Score: 8.548238328445493
# Average of Fitness Scores: 45.21230505799148
# ------------------------------------------------------
# Generation Number: 44
# Best Fitness Score: 59.265939424188566
# Worst Fitness Score: 7.392788887340464
# Average of Fitness Scores: 46.76974469614879
# ------------------------------------------------------
# Generation Number: 45
# Best Fitness Score: 61.12765035573689
# Worst Fitness Score: 8.137315984281836
# Average of Fitness Scores: 41.17910971119887
# ------------------------------------------------------
# Generation Number: 46
# Best Fitness Score: 61.12765035573689
# Worst Fitness Score: 8.930184271025919
# Average of Fitness Scores: 49.670650709548816
# ------------------------------------------------------
# Generation Number: 47
# Best Fitness Score: 62.04818323444171
# Worst Fitness Score: 8.680076493206121
# Average of Fitness Scores: 48.32564501393879
# ------------------------------------------------------
# Generation Number: 48
# Best Fitness Score: 63.2721380511101
# Worst Fitness Score: 8.189233433676204
# Average of Fitness Scores: 50.24342413769698
# ------------------------------------------------------
# Generation Number: 49
# Best Fitness Score: 66.15800899063495
# Worst Fitness Score: 7.945606130520682
# Average of Fitness Scores: 42.57427257358441
# ------------------------------------------------------
# Generation Number: 50
# Best Fitness Score: 66.15800899063495
# Worst Fitness Score: 8.591649040048653
# Average of Fitness Scores: 47.26546417125536
# ------------------------------------------------------
# Generation Number: 51
# Best Fitness Score: 67.14879065507273
# Worst Fitness Score: 8.972761914207627
# Average of Fitness Scores: 57.35206611603291
# ------------------------------------------------------
# Generation Number: 52
# Best Fitness Score: 67.68959980597461
# Worst Fitness Score: 9.335105573363066
# Average of Fitness Scores: 47.00872540125407
# ------------------------------------------------------
# Generation Number: 53
# Best Fitness Score: 67.97443663822864
# Worst Fitness Score: 7.611667891092824
# Average of Fitness Scores: 45.44397799653327
# ------------------------------------------------------
# Generation Number: 54
# Best Fitness Score: 70.36601629529382
# Worst Fitness Score: 7.611667891092824
# Average of Fitness Scores: 48.949969200829585
# ------------------------------------------------------
# Generation Number: 55
# Best Fitness Score: 70.36601629529382
# Worst Fitness Score: 7.703409268384123
# Average of Fitness Scores: 51.03367305117759
# ------------------------------------------------------
# Generation Number: 56
# Best Fitness Score: 70.36601629529382
# Worst Fitness Score: 8.443608794810515
# Average of Fitness Scores: 52.07279354823118
# ------------------------------------------------------
# Generation Number: 57
# Best Fitness Score: 71.64816687020372
# Worst Fitness Score: 9.598161693925011
# Average of Fitness Scores: 59.40079483352582
# ------------------------------------------------------
# Generation Number: 58
# Best Fitness Score: 73.83210212041395
# Worst Fitness Score: 7.8480477026390965
# Average of Fitness Scores: 57.39714280811813
# ------------------------------------------------------
# Answer:
# Return: 10.050570135645332
# Risk: 0.521888829103351
# Num of Purchased Stocks: 400
